# %%
english_geotagged_tweets['method'] = 'Geotagged'

# %%
sns.heatmap(english_geotagged_tweets.isnull())

# %%
sns.heatmap(location_bio_ready_followers.isnull())

# %%
sns.heatmap(arabic_profile_info_tweets.isnull())

# %%
followers_df = pd.DataFrame(data = {'Type of Followers':  ['All Collected Followers','Unique Followers','Public Followers','Tweeted Followers','Joined Before Deadline Followers','Location or Bio Followers','Egyptian Location or Bio Followers'],
                                    'No. of Followers': [437013,224754,212135,131719,65033,45293,4170]
                                    },
                            columns=['Type of Followers','No. of Followers']
)

# %%
followers_df
# Out:
#                     Type of Followers  No. of Followers
# 0             All Collected Followers            437013
# 1                    Unique Followers            224754
# 2                    Public Followers            212135
# 3                   Tweeted Followers            131719
# 4    Joined Before Deadline Followers             65033
# 5           Location or Bio Followers             45293
# 6  Egyptian Location or Bio Followers              4170

# %%
sns.set_style('whitegrid')

# %%
x='Type of Followers'
y='No. of Followers'

plt.figure(figsize=(16,7))
sns.lineplot(x,y, data=followers_df, sort=False, marker='o',lw=3,markersize=12)
plt.tight_layout()

# %%
nearby_df = pd.DataFrame(data = {'Language':  ['Arabic','Arabic','English','English'],
                                'Worked': ['Worked',"Didn't Work",'Worked',"Didn't Work"],
                                 "Governorates Count": [15,12,22,5]
                                    },
                            columns=['Language','Worked',"Governorates Count"]
)

# %%
nearby_df
# Out:
#   Language       Worked  Governorates Count
# 0   Arabic       Worked                  15
# 1   Arabic  Didn't Work                  12
# 2  English       Worked                  22
# 3  English  Didn't Work                   5

# %%
arabic_nearby_df = nearby_df[nearby_df['Language'] == 'Arabic']

# %%
english_nearby_df = nearby_df[nearby_df['Language'] == 'English']

# %%
plt.figure(figsize=(22,8))
h = sns.FacetGrid(nearby_df,col='Language')
h.map(sns.barplot, 'Governorates Count','Worked')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
search_tweets = pd.read_csv('Search Approach/EgyptianSearchTweets.csv')

# %%
search_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
search_tweets.drop_duplicates(inplace=True)

# %%
search_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161336 entries, 0 to 161835
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            161336 non-null  object
#  1   time            161336 non-null  object
#  2   username        161336 non-null  object
#  3   name            161317 non-null  object
#  4   place           142 non-null     object
#  5   tweet           161336 non-null  object
#  6   urls            161336 non-null  object
#  7   replies_count   161336 non-null  int64
#  8   retweets_count  161336 non-null  int64
#  9   likes_count     161336 non-null  int64
#  10  hashtags        161336 non-null  object
#  11  near            0 non-null       float64
#  12  geo             0 non-null       float64
#  13  governorate     161336 non-null  object
#  14  language        161336 non-null  object
#  15  method          161336 non-null  object
# ...

# %%
profile_info_tweets = pd.read_csv('Profile Info Approach/EgyptianProfileInfoTweets.csv')

# %%
profile_info_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
profile_info_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40518 entries, 0 to 40517
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            40518 non-null  object
#  1   time            40518 non-null  object
#  2   username        40518 non-null  object
#  3   name            40518 non-null  object
#  4   place           11 non-null     object
#  5   tweet           40518 non-null  object
#  6   urls            40518 non-null  object
#  7   replies_count   40518 non-null  int64
#  8   retweets_count  40518 non-null  int64
#  9   likes_count     40518 non-null  int64
#  10  hashtags        40518 non-null  object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     40518 non-null  object
#  14  language        40518 non-null  object
#  15  method          40518 non-null  object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
nearby_tweets = pd.read_csv('Nearby Approach/EgyptianNearbyTweets.csv')

# %%
nearby_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
nearby_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180599 entries, 0 to 180598
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            180599 non-null  object
#  1   time            180599 non-null  object
#  2   username        180599 non-null  object
#  3   name            180593 non-null  object
#  4   place           4027 non-null    object
#  5   tweet           180599 non-null  object
#  6   urls            180599 non-null  object
#  7   replies_count   180599 non-null  int64
#  8   retweets_count  180599 non-null  int64
#  9   likes_count     180599 non-null  int64
#  10  hashtags        180599 non-null  object
#  11  near            180599 non-null  object
#  12  geo             0 non-null       float64
#  13  governorate     180599 non-null  object
#  14  language        180599 non-null  object
#  15  method          180599 non-null  object
# ...

# %%
geotagged_tweets.drop_duplicates(inplace=True)

# %%
geotagged_tweets.reset_index(drop=True,inplace=True)

# %%
geotagged_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648747 entries, 0 to 648746
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            648747 non-null  object
#  1   time            648747 non-null  object
#  2   username        648747 non-null  object
#  3   name            648745 non-null  object
#  4   place           5190 non-null    object
#  5   tweet           648747 non-null  object
#  6   urls            648747 non-null  object
#  7   replies_count   648747 non-null  int64
#  8   retweets_count  648747 non-null  int64
#  9   likes_count     648747 non-null  int64
#  10  hashtags        648747 non-null  object
#  11  near            0 non-null       float64
#  12  geo             648747 non-null  object
#  13  governorate     648747 non-null  object
#  14  language        648747 non-null  object
#  15  method          648747 non-null  object
# ...

# %%
tweets_per_approach_df = pd.DataFrame(data = {'Approach':  ['Geocoded','Keyword Search','Nearby','Profile Info'],
                                'No. of tweets': [648747,180599,161336,40518]
                                    },
                            columns=['Approach','No. of tweets']
)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Approach', y='No. of tweets', data=tweets_per_approach_df)

# %%
all_tweets = pd.concat([search_tweets,profile_info_tweets,nearby_tweets,geotagged_tweets])
all_tweets.reset_index(drop=True,inplace=True)

# %%
arabic_search_tweets = pd.read_csv('Search Approach/Arabic/EgyptianArabicSearchTweets3.csv')

# %%
import pandas as pd

# %%
arabic_search_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
arabic_search_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113928 entries, 0 to 113927
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            113928 non-null  object
#  1   time            113928 non-null  object
#  2   username        113928 non-null  object
#  3   name            113926 non-null  object
#  4   place           54 non-null      object
#  5   tweet           113928 non-null  object
#  6   urls            113928 non-null  object
#  7   replies_count   113928 non-null  int64
#  8   retweets_count  113928 non-null  int64
#  9   likes_count     113928 non-null  int64
#  10  hashtags        113928 non-null  object
#  11  near            0 non-null       float64
#  12  geo             0 non-null       float64
#  13  governorate     113928 non-null  object
#  14  language        113928 non-null  object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 13.0+ MB

# %%
arabic_search_tweets['username'].nunique()
# Out:
# 59593

# %%
english_search_tweets = pd.read_csv('Search Approach/English/EgyptianEnglishSearchTweets3.csv')

# %%
english_search_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
english_search_tweets.drop_duplicates(inplace=True)

# %%
english_search_tweets.reset_index(drop=True,inplace=True)

# %%
english_search_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47904 entries, 0 to 47903
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            47904 non-null  object
#  1   time            47904 non-null  object
#  2   username        47904 non-null  object
#  3   name            47887 non-null  object
#  4   place           88 non-null     object
#  5   tweet           47904 non-null  object
#  6   urls            47904 non-null  object
#  7   replies_count   47904 non-null  int64
#  8   retweets_count  47904 non-null  int64
#  9   likes_count     47904 non-null  int64
#  10  hashtags        47904 non-null  object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     47904 non-null  object
#  14  language        47904 non-null  object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 5.5+ MB

# %%
english_search_tweets['username'].nunique()
# Out:
# 29581

# %%
arabic_profile_info_tweets = pd.read_csv('Profile Info Approach/Arabic/EgyptianArabicProfileInfoTweets.csv')

# %%
arabic_profile_info_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
arabic_profile_info_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38813 entries, 0 to 38812
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            38813 non-null  object
#  1   time            38813 non-null  object
#  2   username        38813 non-null  object
#  3   name            38813 non-null  object
#  4   place           9 non-null      object
#  5   tweet           38813 non-null  object
#  6   urls            38813 non-null  object
#  7   replies_count   38813 non-null  int64
#  8   retweets_count  38813 non-null  int64
#  9   likes_count     38813 non-null  int64
#  10  hashtags        38813 non-null  object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     38813 non-null  object
#  14  language        38813 non-null  object
#  15  method          38813 non-null  object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
english_profile_info_tweets = pd.read_csv('Profile Info Approach/English/EgyptianEnglishProfileInfoTweets.csv')

# %%
english_profile_info_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
english_profile_info_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1705 non-null   object
#  1   time            1705 non-null   object
#  2   username        1705 non-null   object
#  3   name            1705 non-null   object
#  4   place           2 non-null      object
#  5   tweet           1705 non-null   object
#  6   urls            1705 non-null   object
#  7   replies_count   1705 non-null   int64
#  8   retweets_count  1705 non-null   int64
#  9   likes_count     1705 non-null   int64
#  10  hashtags        1705 non-null   object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     1705 non-null   object
#  14  language        1705 non-null   object
#  15  method          1705 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
arabic_nearby_tweets = pd.read_csv('Nearby Approach/Arabic/EgyptianArabicNearbyTweets.csv')

# %%
arabic_nearby_tweets.drop('Unnamed: 0', axis=1,inplace=True)

# %%
arabic_nearby_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56539 entries, 0 to 56538
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            56539 non-null  object
#  1   time            56539 non-null  object
#  2   username        56539 non-null  object
#  3   name            56539 non-null  object
#  4   place           1731 non-null   object
#  5   tweet           56539 non-null  object
#  6   urls            56539 non-null  object
#  7   replies_count   56539 non-null  int64
#  8   retweets_count  56539 non-null  int64
#  9   likes_count     56539 non-null  int64
#  10  hashtags        56539 non-null  object
#  11  near            56539 non-null  object
#  12  geo             0 non-null      float64
#  13  governorate     56539 non-null  object
#  14  language        56539 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 6.5+ MB

# %%
english_nearby_tweets = pd.read_csv('Nearby Approach/English/EgyptianEnglishNearbyTweets.csv')

# %%
english_nearby_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124060 entries, 0 to 124059
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            124060 non-null  object
#  1   time            124060 non-null  object
#  2   username        124060 non-null  object
#  3   name            124054 non-null  object
#  4   place           2296 non-null    object
#  5   tweet           124060 non-null  object
#  6   urls            124060 non-null  object
#  7   replies_count   124060 non-null  int64
#  8   retweets_count  124060 non-null  int64
#  9   likes_count     124060 non-null  int64
#  10  hashtags        124060 non-null  object
#  11  near            124060 non-null  object
#  12  geo             0 non-null       float64
#  13  governorate     124060 non-null  object
#  14  language        124060 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 14.2+ MB

# %%
arabic_geocoded_tweets = pd.read_csv('Geotagged Approach/Arabic/EgyptianArabicGeoTweets.csv')

# %%
arabic_geocoded_tweets.drop('Unnamed: 0', axis=1, inplace=True)

# %%
arabic_geocoded_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605400 entries, 0 to 605399
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            605400 non-null  object
#  1   time            605400 non-null  object
#  2   username        605400 non-null  object
#  3   name            605400 non-null  object
#  4   place           4288 non-null    object
#  5   tweet           605400 non-null  object
#  6   urls            605400 non-null  object
#  7   replies_count   605400 non-null  int64
#  8   retweets_count  605400 non-null  int64
#  9   likes_count     605400 non-null  int64
#  10  hashtags        605400 non-null  object
#  11  near            0 non-null       float64
#  12  geo             605400 non-null  object
#  13  governorate     605400 non-null  object
#  14  language        605400 non-null  object
#  15  method          605400 non-null  object
# ...

# %%
english_geocoded_tweets = pd.read_csv('Geotagged Approach/English/EgyptianEnglishGeoTweets.csv')

# %%
english_geocoded_tweets.drop('Unnamed: 0', axis=1, inplace=True)

# %%
english_geocoded_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43353 entries, 0 to 43352
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            43353 non-null  object
#  1   time            43353 non-null  object
#  2   username        43353 non-null  object
#  3   name            43351 non-null  object
#  4   place           902 non-null    object
#  5   tweet           43353 non-null  object
#  6   urls            43353 non-null  object
#  7   replies_count   43353 non-null  int64
#  8   retweets_count  43353 non-null  int64
#  9   likes_count     43353 non-null  int64
#  10  hashtags        43353 non-null  object
#  11  near            0 non-null      float64
#  12  geo             43353 non-null  object
#  13  governorate     43353 non-null  object
#  14  language        43353 non-null  object
#  15  method          43353 non-null  object
# dtypes: float64(1), int64(3), object(12)
# ...

# %%
all_tweets_approach_df = pd.DataFrame(data={'Language': ['Arabic','Arabic','Arabic','Arabic','English','English','English','English'],
                                           'Approach': ['Geocoded','Nearby','Profile Info', 'Keyword Search','Geocoded','Nearby','Profile Info', 'Keyword Search'],
                                           'No. of Tweets': [605400,56539,38813,113928,43353,124060,1705,47904],
                                           'No. of Unique Users': [18451,4268,1436,59593,6512,8631,423,29581]},

                                     columns=['Language','Approach','No. of Tweets','No. of Unique Users']
                                     )

# %%
all_tweets_approach_df
# Out:
#   Language        Approach  No. of Tweets  No. of Unique Users
# 0   Arabic        Geocoded         605400                18451
# 1   Arabic          Nearby          56539                 4268
# 2   Arabic    Profile Info          38813                 1436
# 3   Arabic  Keyword Search         113928                59593
# 4  English        Geocoded          43353                 6512
# 5  English          Nearby         124060                 8631
# 6  English    Profile Info           1705                  423
# 7  English  Keyword Search          47904                29581

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
sns.set_context('paper')
sns.set_style('whitegrid')
sns.barplot(x='Approach',y='No. of Tweets',hue='Language',data=all_tweets_approach_df)

# %%
arabic_search_tweets['username'].nunique()
# Out:
# 59593

# %%
arabic_profile_info_tweets['username'].nunique()
# Out:
# 1436

# %%
arabic_nearby_tweets['username'].nunique()
# Out:
# 4268

# %%
arabic_geocoded_tweets['username'].nunique()
# Out:
# 18451

# %%
english_search_tweets['username'].nunique()
# Out:
# 29581

# %%
english_profile_info_tweets['username'].nunique()
# Out:
# 423

# %%
english_nearby_tweets['username'].nunique()
# Out:
# 8631

# %%
english_geocoded_tweets['username'].nunique()
# Out:
# 6512

# %%
plt.figure(figsize=(10,6))
sns.set_context('paper')
sns.set_style('whitegrid')
sns.barplot(x='Approach',y='No. of Unique Users',hue='Language',data=all_tweets_approach_df)

# %%
tweets_per_approach_df = pd.DataFrame(data = {'Approach':  ['Geocoded','Keyword Search','Nearby','Profile Info'],
                                'No. of tweets': [648747,180599,161336,40518]
                                    },
                            columns=['Approach','No. of tweets'],
                            
)

# %%
tweets_per_approach_df.set_index('Approach',inplace=True)

# %%
tweets_per_approach_df['No. of tweets'].plot.pie()

# %%
pre_sentiment_df = pd.DataFrame({'Ngrams':['Unigram','Unigram','Unigram','Unigram','Unigram','Unigram','Unigram+Bigrams','Unigram+Bigrams','Unigram+Bigrams','Unigram+Bigrams','Unigram+Bigrams','Unigram+Bigrams','Unigram+Bigrams+Trigrams','Unigram+Bigrams+Trigrams','Unigram+Bigrams+Trigrams','Unigram+Bigrams+Trigrams','Unigram+Bigrams+Trigrams','Unigram+Bigrams+Trigrams'],
                                 'Preprocess':['Raw','Raw','Normalized','Normalized','Stemmed','Stemmed','Raw','Raw','Normalized','Normalized','Stemmed','Stemmed','Raw','Raw','Normalized','Normalized','Stemmed','Stemmed'],
                                'Classifier':['Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes','Support Vector Machines','Naive-Bayes'],
                                'Accuracy':[81,82,81,83,83,84,82,83,82,83,84,84,82,82,82,83,84,84]})

# %%
pre_sentiment_df
# Out:
#                       Ngrams  Preprocess               Classifier  Accuracy
# 0                    Unigram         Raw  Support Vector Machines        81
# 1                    Unigram         Raw              Naive-Bayes        82
# 2                    Unigram  Normalized  Support Vector Machines        81
# 3                    Unigram  Normalized              Naive-Bayes        83
# 4                    Unigram     Stemmed  Support Vector Machines        83
# 5                    Unigram     Stemmed              Naive-Bayes        84
# 6            Unigram+Bigrams         Raw  Support Vector Machines        82
# 7            Unigram+Bigrams         Raw              Naive-Bayes        83
# 8            Unigram+Bigrams  Normalized  Support Vector Machines        82
# 9            Unigram+Bigrams  Normalized              Naive-Bayes        83
# 10           Unigram+Bigrams     Stemmed  Support Vector Machines        84
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(pre_sentiment_df.pivot_table(values='Accuracy',index='Classifier',columns=['Ngrams','Preprocess']),annot=True,cmap = sns.cm.rocket_r,linewidths=1)

# %%
governorates = pd.read_csv('Governorates.csv')

# %%
governorates.drop('Unnamed: 0', axis=1, inplace=True)

# %%
governorates.sort_values('% Urban',ascending=False)
# Out:
#               Name Abbr.         Native          Capital    Area  Population  \
# 10           Cairo   QAH        القاهرة       Al-Qāhirah    3085     9539673
# 19       Port Said   BSD       بور سعيد        Būr Sa'īd    1345      749371
# 15            Suez   SWS         السويس        As-Suways    9002      728180
# 5       Alexandria   ISK     الإسكندرية  Al-Iskandariyah    2300     5163750
# 1          Red Sea   BAH   البحر الأحمر     Al-Ghurdaqah  120000      359888
# 22         Matrouh   MTR          مطروخ     Marsā Maṭrūḥ  166563      425624
# 26     North Sinai   SSH     شمال سيناء        Al-'Arīsh   27564      450328
# 7             Giza   JIZ         الجيزة         Al-Jīzah   13184     8632021
# 25     South Sinai   SJN     جنوب سيناء           Aṭ-Ṭūr   31272      102018
# 13      New Valley   WJD  الوادي الجديد      Al-Khārijah  440098      241247
# 6         Ismailia   ISM    الإسماعيلية   Al-Ismā'īliyah    5067     1303993
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(y='Name',x='% Urban',data=governorates.sort_values('% Urban',ascending=False),palette='viridis')
plt.ylabel('Governorate')
# Out:
# Text(0, 0.5, 'Governorate')

# %%
governorates['Urban Population'] = governorates['Population'] * (governorates['% Urban'] /100)

# %%
import math

# %%
governorates['Urban Population'] = governorates['Urban Population'].apply(math.floor)

# %%
plt.figure(figsize=(10,10))
sns.barplot(y='Name',x='Urban Population',data=governorates.sort_values('Urban Population',ascending=False),palette='viridis')
plt.ylabel('Governorate')
# Out:
# Text(0, 0.5, 'Governorate')

# %%
arabic_nearby_tweets['method'] = 'Nearby'

# %%
arabic_search_tweets['method'] = 'Keyword Search'

# %%
def gov_changer(gov):
    if gov == 'Az-Zaqaziq':
        return 'Sharqia'
    if gov == 'Tanta':
        return 'Gharbia'
    return gov

# %%
arabic_search_tweets['governorate'] = arabic_search_tweets['governorate'].apply(gov_changer)

# %%
arabic_tweets = pd.concat([arabic_geocoded_tweets,arabic_nearby_tweets,arabic_profile_info_tweets,arabic_search_tweets])

# %%
arabic_tweets.reset_index(drop=True, inplace=True)

# %%
arabic_no_nearby_tweets = arabic_tweets[arabic_tweets['method'] != 'Nearby']

# %%
arabic_no_nearby_tweets.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(arabic_tweets.isnull())

# %%
arabic_tweets_count = arabic_no_nearby_tweets.groupby('governorate').count()

# %%
arabic_tweets_count
# Out:
#                  date   time  username   name  place  tweet   urls  \
# governorate
# Al-Minya        16162  16162     16162  16162     68  16162  16162
# Alexandria      12610  12610     12610  12610    215  12610  12610
# Aswan           13128  13128     13128  13128     48  13128  13128
# Asyut           10173  10173     10173  10173     27  10173  10173
# Beheira         83932  83932     83932  83932    373  83932  83932
# Beni Suef       10980  10980     10980  10980     40  10980  10980
# Cairo           65773  65773     65773  65772    661  65773  65773
# Dakahlia        87842  87842     87842  87842    187  87842  87842
# Damietta        32647  32647     32647  32647    117  32647  32647
# Fayoum           4679   4679      4679   4679     39   4679   4679
# Gharbia         34295  34295     34295  34295     95  34295  34295
# Giza            89558  89558     89558  89558    749  89558  89558
# Ismailia         9447   9447      9447   9447     42   9447   9447
# ...

# %%
sns.barplot(x='tweet',y=arabic_tweets_count.sort_values('tweet',ascending=False).head(5).index,data=arabic_tweets_count.sort_values('tweet',ascending=False).head(5),palette='magma')
plt.title('Top 5 governorates with # of tweets of all methods')
# Out:
# Text(0.5, 1.0, 'Top 5 governorates with # of tweets of all methods')

# %%
arabic_grouped_geo = arabic_geocoded_tweets.groupby('governorate').count()

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='tweet',y=arabic_grouped_geo.sort_values('tweet',ascending=False).index,data=arabic_grouped_geo.sort_values('tweet',ascending=False),palette='inferno')

# %%
arabic_grouped_profile = arabic_profile_info_tweets.groupby('governorate').count()

# %%
sns.barplot(x='tweet',y=arabic_grouped_profile.sort_values('tweet',ascending=False).head(5).index,data=arabic_grouped_profile.sort_values('tweet',ascending=False).head(5),palette='inferno')
plt.title('Top 5 governorates with # of tweets with Profile Info')
# Out:
# Text(0.5, 1.0, 'Top 5 governorates with # of tweets with Profile Info')

# %%
arabic_grouped_search = arabic_search_tweets.groupby('governorate').count()

# %%
sns.barplot(x='tweet',y=arabic_grouped_search.sort_values('tweet',ascending=False).head(5).index,data=arabic_grouped_search.sort_values('tweet',ascending=False).head(5),palette='inferno')
plt.title('Top 5 governorates with # of tweets with Keyword Search')
# Out:
# Text(0.5, 1.0, 'Top 5 governorates with # of tweets with Keyword Search')

# %%
arabic_users_geo = arabic_geocoded_tweets.reset_index().groupby('governorate')['username'].nunique().to_frame()

# %%
arabic_users_gov_geo = arabic_geocoded_tweets.reset_index().groupby('username')['governorate'].nunique().to_frame().sort_values('governorate', ascending=False)

# %%
arabic_users_gov_geo.head(5)
# Out:
#                  governorate
# username
# mohamed_samy14            14
# aboelwafa005              13
# mohamedk7airyp1           11
# fatmasa82696760           11
# shepoozamalek14           11

# %%
x=arabic_users_gov_geo.head(100).index
sns.set_style('white')
ax = plt.gca()
ax.axes.xaxis.set_visible(False)
sns.scatterplot(x,y='governorate',data=arabic_users_gov_geo.head(100))
plt.title('Top hundered user occurrences in common governorates')
# Out:
# Text(0.5, 1.0, 'Top hundered user occurrences in common governorates')

# %%
arabic_users_gov_search = arabic_search_tweets.reset_index().groupby('username')['governorate'].nunique().to_frame().sort_values('governorate', ascending=False)

# %%
arabic_users_gov_search.head(5)
# Out:
#                governorate
# username
# alahram                 27
# alahramgate             27
# vetogate                26
# aja_egypt               25
# eldostoregypt           25

# %%
arabic_users_gov_geo[arabic_users_gov_geo['governorate'] > 1]
# Out:
#                  governorate
# username
# mohamed_samy14            14
# aboelwafa005              13
# fuckinamr                 12
# mohamedk7airyp1           11
# fatmasa82696760           11
# ...                      ...
# gom3a_tarek                2
# haniadepoon                2
# h0llland                   2
# hazemelzooz70              2
# h__t__l                    2
#
# [10854 rows x 1 columns]

# %%
arabic_users_gov_geo
# Out:
#                  governorate
# username
# mohamed_samy14            14
# aboelwafa005              13
# fuckinamr                 12
# mohamedk7airyp1           11
# fatmasa82696760           11
# ...                      ...
# ashrafbeso6                1
# ashrafe04771646            1
# mohmedxo                   1
# ashrafelbatal24            1
# mostafa12339944            1
#
# [18451 rows x 1 columns]

# %%
represented_by_more_gov_df = pd.DataFrame({'No. of followers represented by':[10854,7597]},
                                         index=['More than one gov','Only one gov'])

# %%
represented_by_more_gov_df['No. of followers represented by'].plot.pie(cmap='coolwarm')

# %%
arabic_users_geo.sort_values('username', ascending=False, inplace=True)

# %%
sns.barplot(y=arabic_users_geo.head(5).index,x='username',data=arabic_users_geo.head(5))
plt.title('Top 5 Governorates with Active Users using Geocode')
# Out:
# Text(0.5, 1.0, 'Top 5 Governorates with Active Users using Geocode')

# %%
arabic_users_search = arabic_search_tweets.reset_index().groupby('governorate')['username'].nunique().to_frame()
arabic_users_search.sort_values('username', ascending=False, inplace=True)

# %%
sns.barplot(y=arabic_users_search.head(5).index,x='username',data=arabic_users_search.head(5))
plt.title('Top 5 Governorates with Active Users using Keyword Search')
# Out:
# Text(0.5, 1.0, 'Top 5 Governorates with Active Users using Keyword Search')

# %%
arabic_users_profile_info = arabic_profile_info_tweets.reset_index().groupby('governorate')['username'].nunique().to_frame()
arabic_users_profile_info.sort_values('username', ascending=False, inplace=True)

# %%
sns.barplot(y=arabic_users_profile_info.head(5).index,x='username',data=arabic_users_profile_info.head(5))
plt.title('Top 5 Governorates with Active Users using Profile Info')
# Out:
# Text(0.5, 1.0, 'Top 5 Governorates with Active Users using Profile Info')

# %%
trial_df = arabic_tweets[['governorate','method']]

# %%
trial_df1 = trial_df[trial_df['method'] == 'Geotagged'].groupby('governorate').count()

# %%
trial_df2 = trial_df[trial_df['method'] == 'Keyword Search'].groupby('governorate').count()

# %%
trial_df3 = trial_df[trial_df['method'] == 'Profile Info'].groupby('governorate').count()

# %%
trial_df1.rename({'method':'Geocoded'},axis=1,inplace=True)

# %%
trial_df2.rename({'method':'Keyword Search'},axis=1,inplace=True)

# %%
trial_df3.rename({'method':'Profile Info'},axis=1,inplace=True)

# %%
trial_df1 = trial_df1.join(trial_df2,on='governorate')

# %%
trial_df1 = trial_df1.join(trial_df3,on='governorate')

# %%
trial_df1.fillna(0, inplace=True)

# %%
best_approach=[]
for i in range(0,len(trial_df1)):
    row = trial_df1.iloc[i]
    best = row.max()
    if best == row['Geocoded']:
        best_approach.append('Geocoded')
    if best == row['Profile Info']:
        best_approach.append('Profile Info')
    if best == row['Keyword Search']:
        best_approach.append('Keyword Search')
best_approach
# Out:
# ['Geocoded',
#  'Profile Info',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Keyword Search',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Keyword Search',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Geocoded',
#  'Profile Info',
#  'Geocoded',
#  'Geocoded',
#  'Keyword Search',
#  'Geocoded',
#  'Geocoded']

# %%
trial_df1['Most Approach'] = best_approach

# %%
import numpy as numpy

# %%
trial_df1
# Out:
#                 Geocoded  Keyword Search  Profile Info   Most Approach
# governorate
# Al-Minya           12591            3312         259.0        Geocoded
# Alexandria           378            5773        6459.0    Profile Info
# Aswan               7399            4673        1056.0        Geocoded
# Asyut               5926            4123         124.0        Geocoded
# Beheira            81742            1808         382.0        Geocoded
# Beni Suef           8641            2270          69.0        Geocoded
# Cairo              15957           38054       11762.0  Keyword Search
# Dakahlia           82291            4220        1331.0        Geocoded
# Damietta           22371            8024        2252.0        Geocoded
# Fayoum              2890            1664         125.0        Geocoded
# Gharbia            25838            4889        3568.0        Geocoded
# Giza               83585            3626        2347.0        Geocoded
# ...

# %%
trial_df1.groupby('Most Approach').count()['Geocoded'].plot.pie(cmap='viridis')
plt.xlabel('Approach with the most collected per governorate')
plt.ylabel('')
plt.tight_layout()

# %%
corona_tweets = arabic_tweets[arabic_tweets['corona'] == True]

# %%
corona_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56885 entries, 23 to 758139
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            56885 non-null  object
#  1   time            56885 non-null  object
#  2   username        56885 non-null  object
#  3   name            56885 non-null  object
#  4   place           308 non-null    object
#  5   tweet           56885 non-null  object
#  6   urls            56885 non-null  object
#  7   replies_count   56885 non-null  int64
#  8   retweets_count  56885 non-null  int64
#  9   likes_count     56885 non-null  int64
#  10  hashtags        56885 non-null  object
#  11  near            0 non-null      object
#  12  geo             31704 non-null  object
#  13  governorate     56885 non-null  object
#  14  language        56885 non-null  object
#  15  method          56885 non-null  object
#  16  corona          56885 non-null  bool
# ...

# %%
arabic_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758141 entries, 0 to 758140
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            758141 non-null  object
#  1   time            758141 non-null  object
#  2   username        758141 non-null  object
#  3   name            758139 non-null  object
#  4   place           4351 non-null    object
#  5   tweet           758141 non-null  object
#  6   urls            758141 non-null  object
#  7   replies_count   758141 non-null  int64
#  8   retweets_count  758141 non-null  int64
#  9   likes_count     758141 non-null  int64
#  10  hashtags        758141 non-null  object
#  11  near            0 non-null       object
#  12  geo             605400 non-null  object
#  13  governorate     758141 non-null  object
#  14  language        758141 non-null  object
#  15  method          758141 non-null  object
# ...

# %%
corona_mentions = pd.DataFrame({'No. of mentions':[56885,701256]},
                              index=['Corona mentions','Non-corona mentions'])

# %%
sns.barplot(x=corona_mentions.index,y='No. of mentions',data=corona_mentions)

# %%
corona_mentions['No. of mentions'].plot.pie(cmap='PiYG',autopct='%.1f')
plt.ylabel('')
plt.title('COVID-19 mentions in tweets opposite to non COVID-19 mentions')
plt.tight_layout()

# %%
corona_date = corona_tweets.groupby('date').count()

# %%
corona_date.drop('2020-03-22')
# Out:
#             time  username  name  place  tweet  urls  replies_count  \
# date
# 2020-03-08  2175      2175  2175     11   2175  2175           2175
# 2020-03-09  2381      2381  2381      6   2381  2381           2381
# 2020-03-10  2676      2676  2676     28   2676  2676           2676
# 2020-03-11  2382      2382  2382     12   2382  2382           2382
# 2020-03-12  2902      2902  2902     32   2902  2902           2902
# 2020-03-13  2880      2880  2880      8   2880  2880           2880
# 2020-03-14  4293      4293  4293     17   4293  4293           4293
# 2020-03-15  4300      4300  4300     32   4300  4300           4300
# 2020-03-16  4944      4944  4944     23   4944  4944           4944
# 2020-03-17  5416      5416  5416     21   5416  5416           5416
# 2020-03-18  4833      4833  4833     35   4833  4833           4833
# 2020-03-19  4876      4876  4876     24   4876  4876           4876
# 2020-03-20  7283      7283  7283     23   7283  7283           7283
# ...

# %%
plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
sns.lineplot(x=corona_date.drop('2020-03-22').index,y='tweet',data=corona_date.drop('2020-03-22'),marker='o',markersize=8,lw=2)
plt.title('# of COVID-19 tweets per day')
plt.tight_layout()

# %%
corona_gov = corona_tweets.groupby('governorate').count()

# %%
corona_gov = corona_gov.sort_values('tweet',ascending=False)

# %%
sns.barplot(y=corona_gov.head(5).index,x='tweet',data=corona_gov.head(5),palette='viridis')
plt.title('Top 5 governorates with # of tweets')
# Out:
# Text(0.5, 1.0, 'Top 5 governorates with # of tweets')

# %%
arabic_tweet_count = arabic_tweets.groupby('governorate').count()['tweet'].to_frame().reset_index()

# %%
arabic_tweet_count.rename({'governorate':'Name'}, axis=1, inplace=True)

# %%
governorates = pd.merge(governorates,arabic_tweet_count,on='Name')

# %%
governorates.rename({'tweet':'Tweet Count'}, axis=1, inplace=True)

# %%
governorates
# Out:
#               Name Abbr.         Native          Capital    Area  Population  \
# 0         Dakahlia   DQH       الدقهلية      Al-Manṣūrah    3538     6492381
# 1          Red Sea   BAH   البحر الأحمر     Al-Ghurdaqah  120000      359888
# 2          Beheira   BHR        البحيرة         Damanhūr    9826     6171613
# 3           Fayoum   FYM         الفيوم        Al-Fayyūm    6068     3596954
# 4          Gharbia   GHB        الغربية            Ṭanṭā    1942     4999633
# 5       Alexandria   ISK     الإسكندرية  Al-Iskandariyah    2300     5163750
# 6         Ismailia   ISM    الإسماعيلية   Al-Ismā'īliyah    5067     1303993
# 7             Giza   JIZ         الجيزة         Al-Jīzah   13184     8632021
# 8          Monufia   MNF       المنوفية   Shibīn al-Kawm    2499     4301601
# 9         Al-Minya   MNY         المنيا         Al-Minyā   32279     5497095
# 10           Cairo   QAH        القاهرة       Al-Qāhirah    3085     9539673
# ...

# %%
corona_gov_count = corona_gov['tweet'].to_frame().reset_index()

# %%
corona_gov_count.rename({'governorate':'Name'},axis=1,inplace=True)

# %%
governorates = pd.merge(governorates,corona_gov_count,on='Name')

# %%
governorates.rename({'tweet':'Corona Tweets'}, axis=1, inplace=True)

# %%
governorates['% Corona'] = ((governorates['Corona Tweets']/governorates['Tweet Count'])*100)

# %%
governorates.sort_values('% Corona',ascending=False)
# Out:
#               Name Abbr.         Native          Capital    Area  Population  \
# 12           Luxor   UQS         الأقصر         Al-Uqṣur    2960     1250209
# 10           Cairo   QAH        القاهرة       Al-Qāhirah    3085     9539673
# 17           Asyut   ASY          أسيوط            Asyūṭ   13720     4383289
# 23            Qena   QNA            قنا             Qinā    8980     3164281
# 25     South Sinai   SJN     جنوب سيناء           Aṭ-Ṭūr   31272      102018
# 5       Alexandria   ISK     الإسكندرية  Al-Iskandariyah    2300     5163750
# 16           Aswan   ASW          أسوان            Aswān   62726     1473975
# 19       Port Said   BSD       بور سعيد        Būr Sa'īd    1345      749371
# 1          Red Sea   BAH   البحر الأحمر     Al-Ghurdaqah  120000      359888
# 20        Damietta   DMY          دمياط           Dumyāṭ     910     1496765
# 9         Al-Minya   MNY         المنيا         Al-Minyā   32279     5497095
# ...

# %%
corona_search_tweets = corona_tweets[corona_tweets['method'] == 'Keyword Search']

# %%
corona_search_tweets = corona_search_tweets.groupby('governorate').count()['tweet'].to_frame().reset_index().sort_values('tweet',ascending=False)

# %%
sns.barplot(x='tweet',y='governorate',data=corona_search_tweets.head(5),palette='viridis')
plt.title('Top 5 governorates searched with COVID-19 mentions')
# Out:
# Text(0.5, 1.0, 'Top 5 governorates searched with COVID-19 mentions')

# %%
X_train, X_test, y_train, y_test = train_test_split(training_data['stem_tweet'], training_data['sentiment'], test_size=0.2, random_state=101)

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer(ngram_range=(1,2))),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('bow',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 2), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('classifier',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
predictions = pipeline.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       341
#            1       0.87      0.82      0.84       368
#
#     accuracy                           0.84       709
#    macro avg       0.84      0.84      0.84       709
# weighted avg       0.85      0.84      0.84       709

# %%
corona_tweets['clean_tweet'] = corona_tweets['tweet'].apply(normalize_stem_tweet_ar)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
corona_tweets['sentiment'] = pipeline.predict(corona_tweets['clean_tweet'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def sentiment_str(sentiment):
    if sentiment == 0:
        return 'Negative'
    else:
        return 'Positive'

# %%
corona_tweets['sentiment_str'] = corona_tweets['sentiment'].apply(sentiment_str)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.set_style('whitegrid')
sns.set_context('paper')
sns.countplot('sentiment_str',data=corona_tweets,palette='viridis')
plt.xlabel('')
plt.ylabel('tweets')
plt.title('COVID-19 Negative and Positive tweets count')
# Out:
# Text(0.5, 1.0, 'COVID-19 Negative and Positive tweets count')
