# %%
sample_test = sample_test[['date','time','username','name','place','tweet','near','geo']]

# %%
sns.heatmap(sample_test.iloc[[0,50]].isnull(),cbar=False)
plt.ylabel('Tweet ID #')
plt.tight_layout()
plt.locator_params(axis='y', nbins=15)
plt.title('Data presence in features')
# Out:
# Text(0.5, 1, 'Data presence in features')

# %%
eg_profile_info = pd.read_csv('Profile Info Approach/EgyptianProfileInfoTweets.csv')

# %%
eg_profile_info = pd.read_csv('Profile Info Approach/Governorated Followers Info.csv')

# %%
sum(eg_profile_info['governorate_loc'] != 'Not Found')
# Out:
# 3692

# %%
sum(eg_profile_info['governorate_bio'] != 'Not Found')
# Out:
# 577

# %%
df = pd.DataFrame({'# of users':[3692,577]},index=['Found by location', 'Found by bio'])

# %%
sns.barplot(x=df.index, y='# of users',data=df,palette='inferno')

# %%
ar_geo = pd.read_csv('Geotagged Approach/Arabic/EgyptianArabicGeoTweets.csv')

# %%
ar_search = pd.read_csv('Search Approach/Arabic/EgyptianArabicSearchTweets3.csv')

# %%
ar_profile = pd.read_csv('Profile Info Approach/Arabic/EgyptianArabicProfileInfoTweets.csv')

# %%
ar_nearby = pd.read_csv('Nearby Approach/Arabic/EgyptianArabicNearbyTweets.csv')

# %%
ar_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605394 entries, 0 to 605399
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            605394 non-null  object
#  1   time            605394 non-null  object
#  2   username        605394 non-null  object
#  3   name            605394 non-null  object
#  4   place           4288 non-null    object
#  5   tweet           605394 non-null  object
#  6   urls            605394 non-null  object
#  7   replies_count   605394 non-null  int64
#  8   retweets_count  605394 non-null  int64
#  9   likes_count     605394 non-null  int64
#  10  hashtags        605394 non-null  object
#  11  near            0 non-null       float64
#  12  geo             605394 non-null  object
#  13  governorate     605394 non-null  object
#  14  language        605394 non-null  object
#  15  method          605394 non-null  object
# ...

# %%
ar_search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113432 entries, 0 to 113927
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            113432 non-null  object
#  1   time            113432 non-null  object
#  2   username        113432 non-null  object
#  3   name            113430 non-null  object
#  4   place           54 non-null      object
#  5   tweet           113432 non-null  object
#  6   urls            113432 non-null  object
#  7   replies_count   113432 non-null  int64
#  8   retweets_count  113432 non-null  int64
#  9   likes_count     113432 non-null  int64
#  10  hashtags        113432 non-null  object
#  11  near            0 non-null       float64
#  12  geo             0 non-null       float64
#  13  governorate     113432 non-null  object
#  14  language        113432 non-null  object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 13.8+ MB

# %%
ar_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38813 entries, 0 to 38812
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            38813 non-null  object
#  1   time            38813 non-null  object
#  2   username        38813 non-null  object
#  3   name            38813 non-null  object
#  4   place           9 non-null      object
#  5   tweet           38813 non-null  object
#  6   urls            38813 non-null  object
#  7   replies_count   38813 non-null  int64
#  8   retweets_count  38813 non-null  int64
#  9   likes_count     38813 non-null  int64
#  10  hashtags        38813 non-null  object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     38813 non-null  object
#  14  language        38813 non-null  object
#  15  method          38813 non-null  object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
ar_nearby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56539 entries, 0 to 56538
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            56539 non-null  object
#  1   time            56539 non-null  object
#  2   username        56539 non-null  object
#  3   name            56539 non-null  object
#  4   place           1731 non-null   object
#  5   tweet           56539 non-null  object
#  6   urls            56539 non-null  object
#  7   replies_count   56539 non-null  int64
#  8   retweets_count  56539 non-null  int64
#  9   likes_count     56539 non-null  int64
#  10  hashtags        56539 non-null  object
#  11  near            56539 non-null  object
#  12  geo             0 non-null      float64
#  13  governorate     56539 non-null  object
#  14  language        56539 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 6.9+ MB

# %%
en_geo = pd.read_csv('Geotagged Approach/English/EgyptianEnglishGeoTweets.csv')

# %%
en_search = pd.read_csv('Search Approach/English/EgyptianEnglishSearchTweets3.csv')

# %%
en_profile = pd.read_csv('Profile Info Approach/English/EgyptianEnglishProfileInfoTweets.csv')

# %%
en_nearby = pd.read_csv('Nearby Approach/English/EgyptianEnglishNearbyTweets.csv')

# %%
en_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43353 entries, 0 to 43352
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            43353 non-null  object
#  1   time            43353 non-null  object
#  2   username        43353 non-null  object
#  3   name            43351 non-null  object
#  4   place           902 non-null    object
#  5   tweet           43353 non-null  object
#  6   urls            43353 non-null  object
#  7   replies_count   43353 non-null  int64
#  8   retweets_count  43353 non-null  int64
#  9   likes_count     43353 non-null  int64
#  10  hashtags        43353 non-null  object
#  11  near            0 non-null      float64
#  12  geo             43353 non-null  object
#  13  governorate     43353 non-null  object
#  14  language        43353 non-null  object
#  15  method          43353 non-null  object
# dtypes: float64(1), int64(3), object(12)
# ...

# %%
en_search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47904 entries, 0 to 47907
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            47904 non-null  object
#  1   time            47904 non-null  object
#  2   username        47904 non-null  object
#  3   name            47887 non-null  object
#  4   place           88 non-null     object
#  5   tweet           47904 non-null  object
#  6   urls            47904 non-null  object
#  7   replies_count   47904 non-null  int64
#  8   retweets_count  47904 non-null  int64
#  9   likes_count     47904 non-null  int64
#  10  hashtags        47904 non-null  object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     47904 non-null  object
#  14  language        47904 non-null  object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 5.8+ MB

# %%
en_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1705 entries, 0 to 1704
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1705 non-null   object
#  1   time            1705 non-null   object
#  2   username        1705 non-null   object
#  3   name            1705 non-null   object
#  4   place           2 non-null      object
#  5   tweet           1705 non-null   object
#  6   urls            1705 non-null   object
#  7   replies_count   1705 non-null   int64
#  8   retweets_count  1705 non-null   int64
#  9   likes_count     1705 non-null   int64
#  10  hashtags        1705 non-null   object
#  11  near            0 non-null      float64
#  12  geo             0 non-null      float64
#  13  governorate     1705 non-null   object
#  14  language        1705 non-null   object
#  15  method          1705 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
en_nearby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124060 entries, 0 to 124059
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            124060 non-null  object
#  1   time            124060 non-null  object
#  2   username        124060 non-null  object
#  3   name            124054 non-null  object
#  4   place           2296 non-null    object
#  5   tweet           124060 non-null  object
#  6   urls            124060 non-null  object
#  7   replies_count   124060 non-null  int64
#  8   retweets_count  124060 non-null  int64
#  9   likes_count     124060 non-null  int64
#  10  hashtags        124060 non-null  object
#  11  near            124060 non-null  object
#  12  geo             0 non-null       float64
#  13  governorate     124060 non-null  object
#  14  language        124060 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 15.1+ MB

# %%
df = pd.DataFrame({'# of tweets':[814178,217022]},index=['Arabic', 'English'])

# %%
sns.set_style('whitegrid')
sns.set_context('paper')
sns.barplot(x=df.index,y='# of tweets',data=df,palette='inferno')

# %%
governorates = pd.read_csv('Governorates.csv')

# %%
governorates.drop('Unnamed: 0', axis=1, inplace=True)

# %%
governorates['Urban Area'] = governorates['Area'] * governorates['% Urban']/100

# %%
governorates
# Out:
#               Name Abbr.         Native          Capital    Area  Population  \
# 0         Dakahlia   DQH       الدقهلية      Al-Manṣūrah    3538     6492381
# 1          Red Sea   BAH   البحر الأحمر     Al-Ghurdaqah  120000      359888
# 2          Beheira   BHR        البحيرة         Damanhūr    9826     6171613
# 3           Fayoum   FYM         الفيوم        Al-Fayyūm    6068     3596954
# 4          Gharbia   GHB        الغربية            Ṭanṭā    1942     4999633
# 5       Alexandria   ISK     الإسكندرية  Al-Iskandariyah    2300     5163750
# 6         Ismailia   ISM    الإسماعيلية   Al-Ismā'īliyah    5067     1303993
# 7             Giza   JIZ         الجيزة         Al-Jīzah   13184     8632021
# 8          Monufia   MNF       المنوفية   Shibīn al-Kawm    2499     4301601
# 9         Al-Minya   MNY         المنيا         Al-Minyā   32279     5497095
# 10           Cairo   QAH        القاهرة       Al-Qāhirah    3085     9539673
# ...

# %%
sns.lmplot(y='% Urban', x='Density', data=governorates)

# %%
governorates['Urban Population'] = governorates['Population'] * governorates['% Urban']/100

# %%
governorates
# Out:
#               Name Abbr.         Native          Capital    Area  Population  \
# 0         Dakahlia   DQH       الدقهلية      Al-Manṣūrah    3538     6492381
# 1          Red Sea   BAH   البحر الأحمر     Al-Ghurdaqah  120000      359888
# 2          Beheira   BHR        البحيرة         Damanhūr    9826     6171613
# 3           Fayoum   FYM         الفيوم        Al-Fayyūm    6068     3596954
# 4          Gharbia   GHB        الغربية            Ṭanṭā    1942     4999633
# 5       Alexandria   ISK     الإسكندرية  Al-Iskandariyah    2300     5163750
# 6         Ismailia   ISM    الإسماعيلية   Al-Ismā'īliyah    5067     1303993
# 7             Giza   JIZ         الجيزة         Al-Jīzah   13184     8632021
# 8          Monufia   MNF       المنوفية   Shibīn al-Kawm    2499     4301601
# 9         Al-Minya   MNY         المنيا         Al-Minyā   32279     5497095
# 10           Cairo   QAH        القاهرة       Al-Qāhirah    3085     9539673
# ...

# %%
sns.lmplot(y='% Urban', x='Urban Population', data=governorates.drop([5,7,10]))

# %%
governorates.sort_values('Density', ascending=False)
# Out:
#               Name Abbr.         Native          Capital    Area  Population  \
# 11        Qalyubia   QLY      القليوبية            Banhā    1124     5627420
# 10           Cairo   QAH        القاهرة       Al-Qāhirah    3085     9539673
# 4          Gharbia   GHB        الغربية            Ṭanṭā    1942     4999633
# 5       Alexandria   ISK     الإسكندرية  Al-Iskandariyah    2300     5163750
# 0         Dakahlia   DQH       الدقهلية      Al-Manṣūrah    3538     6492381
# 8          Monufia   MNF       المنوفية   Shibīn al-Kawm    2499     4301601
# 20        Damietta   DMY          دمياط           Dumyāṭ     910     1496765
# 14         Sharqia   SQY        الشرقية       Az-Zaqāzīq    4911     7163824
# 21  Kafr el-Sheikh   KSH      كفر الشيخ  Kafr ash-Shaykh    3467     3362185
# 7             Giza   JIZ         الجيزة         Al-Jīzah   13184     8632021
# 2          Beheira   BHR        البحيرة         Damanhūr    9826     6171613
# ...

# %%
arabic_tweets = pd.read_csv('ArabicTweetsSentiment.csv')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
arabic_tweets.drop('Unnamed: 0', axis=1, inplace=True)

# %%
no_geo = arabic_tweets[arabic_tweets['method'] != 'Geotagged']

# %%
no_geo['governorate'].unique()
# Out:
# array(['Cairo', 'Sharqia', 'Suez', 'Dakahlia', 'Monufia', 'Giza',
#        'North Sinai', 'Alexandria', 'Damietta', 'Gharbia', 'Aswan',
#        'Luxor', 'Beheira', 'Qena', 'Qalyubia', 'Sohag', 'Fayoum',
#        'Beni Suef', 'Ismailia', 'Kafr el-Sheikh', 'Al-Minya', 'Asyut',
#        'Port Said', 'South Sinai', 'Matrouh', 'Red Sea', 'New Valley'],
#       dtype=object)

# %%
def gov_changer(governorate):
    if governorate == 'Az-Zaqaziq':
        return 'Sharqia'
    if governorate == 'Tanta':
        return 'Gharbia'
    return governorate

# %%
arabic_tweets.to_csv('ArabicTweets.csv', index=False)

# %%
arabic_tweets['governorate'] = arabic_tweets['governorate'].apply(gov_changer)

# %%
no_geo.groupby('governorate').count().sort_values('tweet', ascending=False)
# Out:
#                  date   time  username   name  place  tweet   urls  \
# governorate
# Cairo           49816  49816     49816  49815     22  49816  49816
# Alexandria      12232  12232     12232  12232      3  12232  12232
# Damietta         9780   9780      9780   9780      4   9780   9780
# Gharbia          8457   8457      8457   8457      2   8457   8457
# Suez             6514   6514      6514   6514      1   6514   6514
# Giza             5973   5973      5973   5973      0   5973   5973
# Aswan            5729   5729      5729   5729      2   5729   5729
# Dakahlia         5551   5551      5551   5551      0   5551   5551
# Luxor            5071   5071      5071   5071      1   5071   5071
# Sharqia          4379   4379      4379   4379      2   4379   4379
# Asyut            4247   4247      4247   4247      1   4247   4247
# Monufia          3832   3832      3832   3832      0   3832   3832
# Port Said        3692   3692      3692   3692      2   3692   3692
# ...

# %%
arabic_tweets.groupby('governorate').count().sort_values('tweet', ascending=False)
# Out:
#                  date   time  username   name  place  tweet   urls  \
# governorate
# Giza            89557  89557     89557  89557    749  89557  89557
# Dakahlia        87842  87842     87842  87842    187  87842  87842
# Beheira         83932  83932     83932  83932    373  83932  83932
# Cairo           65773  65773     65773  65772    661  65773  65773
# Matrouh         58303  58303     58303  58303    340  58303  58303
# Kafr el-Sheikh  41593  41593     41593  41592    210  41593  41593
# Sharqia         36712  36712     36712  36712    195  36712  36712
# Gharbia         34293  34293     34293  34293     95  34293  34293
# Damietta        32151  32151     32151  32151    117  32151  32151
# New Valley      31436  31436     31436  31436    251  31436  31436
# Suez            21017  21017     21017  21017     81  21017  21017
# Monufia         20054  20054     20054  20054    130  20054  20054
# Red Sea         19906  19906     19906  19906    156  19906  19906
# ...

# %%
geo = arabic_tweets[arabic_tweets['method'] == 'Geotagged']

# %%
geo_gov_tweets = geo.groupby('governorate').count().sort_values('tweet', ascending=False)

# %%
no_geo_gov_tweets = no_geo.groupby('governorate').count().sort_values('tweet', ascending=False)

# %%
sns.barplot(y=geo_gov_tweets.head(5).index, x='tweet',data=geo_gov_tweets.head(5), palette='magma')

# %%
search = arabic_tweets[arabic_tweets['method'] == 'Keyword Search']

# %%
search_gov_tweets = search.groupby('governorate').count().sort_values('tweet', ascending=False)

# %%
sns.barplot(y=search_gov_tweets.head(5).index, x='tweet',data=search_gov_tweets.head(5), palette='magma')

# %%
profile = arabic_tweets[arabic_tweets['method'] == 'Profile Info']

# %%
profile_gov_tweets = profile.groupby('governorate').count().sort_values('tweet', ascending=False)

# %%
sns.barplot(y=profile_gov_tweets.head(5).index, x='tweet',data=profile_gov_tweets.head(5), palette='magma')

# %%
geo_gov_users = geo.groupby('governorate').count().sort_values('username', ascending=False)

# %%
geo2 = geo.groupby(['governorate','username']).count().reset_index()
geo_gov_users = geo2[['governorate','username']].groupby('governorate').count().sort_values('username', ascending=False)

# %%
sns.barplot(y=geo_gov_users.head(5).index, x='username',data=geo_gov_users.head(5))
plt.xlabel('Active Users Count')
# Out:
# Text(0.5, 0, 'Active Users Count')

# %%
search2 = search.groupby(['governorate','username']).count().reset_index()
search_gov_users = search2[['governorate','username']].groupby('governorate').count().sort_values('username', ascending=False)

# %%
sns.barplot(y=search_gov_users.head(5).index, x='username',data=search_gov_users.head(5))
plt.xlabel('Active Users Count')
# Out:
# Text(0.5, 0, 'Active Users Count')

# %%
profile2 = profile.groupby(['governorate','username']).count().reset_index()
profile_gov_users = profile2[['governorate','username']].groupby('governorate').count().sort_values('username', ascending=False)

# %%
sns.barplot(y=profile_gov_users.head(5).index, x='username',data=profile_gov_users.head(5))
plt.xlabel('Active Users Count')
# Out:
# Text(0.5, 0, 'Active Users Count')
